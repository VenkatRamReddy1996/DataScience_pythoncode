# %% [markdown]
# # Hierarchial Clustering

# %%
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %%
Airlines= pd.read_csv("EastWestAirlines (1).csv")
Airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines.rename(columns = {'Award?':'Award'}, inplace = True)

# %%
Airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award              3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    print(x)
    return x

# %%
Airlines.iloc[:,1:]
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
Airlines.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
def_norm = norm_func(Airlines.iloc[:,1:])
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
def_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
dendogram = sch.dendrogram(sch.linkage(def_norm,method='average'))

# %%
hc = AgglomerativeClustering(n_clusters=3,metric='euclidean',distance_threshold=None)

# %%
y_hc = hc.fit_predict(def_norm)

# %%
set(y_hc)
# Out:
# {0, 1, 2}

# %%
Airlines['h_clusteroid']=y_hc

# %%
Airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines1 = Airlines.sort_values("h_clusteroid")
Airlines1
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 1999  2016   327126        1452          5          1          1        97997
# 1459  1473   315273           0          1          1          1        12584
# 1455  1469    49438           0          4          1          1        33912
# 3069  3091   105544           0          4          1          1        31001
# 1452  1466   147822           0          4          1          1        42469
# ...    ...      ...         ...        ...        ...        ...          ...
# 3341  3364    39566           0          2          1          1        23755
# 3343  3366    41628           0          3          1          1        16771
# 1057  1068   235567           0          3          1          1        16106
# 1074  1085    70877           0          2          1          1         8956
# 2360  2378   142244           0          3          1          1        12325
#
# ...

# %%
Airlines1.groupby("h_clusteroid").mean()
# Out:
#                       ID#        Balance  Qual_miles  cc1_miles  cc2_miles  \
# h_clusteroid
# 0             1745.592843   97053.051317  240.196489   2.661715   1.015530
# 1             2312.702339   37876.890058   52.797076   1.000000   1.019883
# 2             1877.870050  106221.111386  161.262376   3.198020   1.001238
#
#               cc3_miles   Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# h_clusteroid
# 0              1.018231  28905.414585    15.782579         857.501013
# 1              1.000585   2558.508187     5.730994         239.314035
# 2              1.025990  26458.257426    16.363861         198.733911
#
#               Flight_trans_12  Days_since_enroll  Award
# h_clusteroid
# 0                    2.599595        4625.062120    1.0
# 1                    0.697076        3562.376608    0.0
# 2                    0.558168        4367.250000    0.0

# %% [markdown]
# # K-Means Clustering

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
from sklearn.cluster import KMeans

# %%
Airlines = pd.read_csv("EastWestAirlines (1).csv")
Airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines.rename(columns = {'Award?':'Award'}, inplace = True)

# %%
Airlines.describe()
# Out:
#                ID#       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %%
Airlines1 = Airlines.iloc[:,1:]

# %%
Airlines.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award'],
#       dtype='object')

# %%
Airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award              3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
from sklearn.preprocessing import StandardScaler
Scaler = StandardScaler()
Scaled_Airlines_df = pd.DataFrame(Scaler.fit_transform(Airlines.iloc[:,1:]),columns=['Balance','Qual_miles','cc1_miles','cc2_miles','cc3_miles',
                                                                                     'Bonus_miles','Bonus_trans', 'Flight_miles_12mo', 
                                                                                     'Flight_trans_12',
                                                                                     'Days_since_enroll', 'Award'])
Scaled_Airlines_df
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0    -0.451141   -0.186299  -0.769578  -0.098242  -0.062767    -0.702786
# 1    -0.539457   -0.186299  -0.769578  -0.098242  -0.062767    -0.701088
# 2    -0.320031   -0.186299  -0.769578  -0.098242  -0.062767    -0.539253
# 3    -0.583799   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 4     0.239678   -0.186299   1.409471  -0.098242  -0.062767     1.083121
# ...        ...         ...        ...        ...        ...          ...
# 3994 -0.547079   -0.186299  -0.769578  -0.098242  -0.062767    -0.356960
# 3995 -0.091465   -0.186299  -0.769578  -0.098242  -0.062767    -0.669367
# 3996 -0.000043   -0.186299   0.683121  -0.098242  -0.062767     0.343804
# 3997 -0.185607   -0.186299  -0.769578  -0.098242  -0.062767    -0.689286
# 3998 -0.700508   -0.186299  -0.769578  -0.098242  -0.062767    -0.709992
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
wcss=[]
for i in range(1,10):
    kmeans=KMeans(n_clusters=i,random_state=42)
    kmeans.fit(Scaled_Airlines_df)
    wcss.append(kmeans.inertia_)
print(wcss)
plt.plot(range(1,10),wcss)
plt.plot('Elbow Method')
plt.plot('Number of Clusters')
plt.plot('WCSS')
plt.show()
# Out:
# [43988.999999999985, 35409.5166298613, 30906.110883899542, 27154.331168950815, 24541.471294111238, 21089.694784806925, 18891.92670311129, 17316.774877029922, 15961.476009310602]

# %%
from sklearn.cluster import KMeans
cluster_new = KMeans(3,random_state=42)
cluster_new.fit(Scaled_Airlines_df)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
cluster_new.labels_
# Out:
# array([1, 1, 1, ..., 0, 1, 1])

# %%
set(cluster_new.labels_)
# Out:
# {0, 1, 2}

# %%
Airlines['clusteroid_new']= cluster_new.labels_

# %%
Airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines.sort_values(by='clusteroid_new')
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 1999  2016   327126        1452          5          1          1        97997
# 1388  1402   156041           0          2          1          1         5644
# 1385  1399    14345           0          4          1          1        50752
# 1384  1398   320997        2556          5          1          1        82255
# 1382  1396    66516           0          4          1          1        45406
# ...    ...      ...         ...        ...        ...        ...          ...
# 958    969    13375        4301          4          1          1        15732
# 275    279  1704838           0          1          1          1        17108
# 2903  2925     2900           0          1          1          1         2900
# 662    671   109532           0          5          1          1       128048
# 833    843   114932        8559          1          1          1         3150
#
# ...

# %%
cluster_new.cluster_centres_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 cluster_new.cluster_centres_
#
# AttributeError: 'KMeans' object has no attribute 'cluster_centres_'

# %%
Airlines.groupby('clusteroid_new').agg(['mean']).reset_index()
# Out:
#   clusteroid_new          ID#        Balance  Qual_miles cc1_miles cc2_miles  \
#                          mean           mean        mean      mean      mean
# 0              0  1600.939807  117635.571429  126.030498  3.744783  1.002408
# 1              1  2233.072896   44429.433114   98.345483  1.237301  1.019000
# 2              2  1743.660920  190656.775862  951.994253  2.178161  1.034483
#
#   cc3_miles   Bonus_miles Bonus_trans Flight_miles_12mo Flight_trans_12  \
#        mean          mean        mean              mean            mean
# 0  1.036918  40624.182986   19.012039        333.447030        0.990369
# 1  1.000388   4854.212098    7.019775        198.970531        0.622334
# 2  1.011494  31181.005747   26.454023       5236.454023       15.252874
#
#   Days_since_enroll     Award
#                mean      mean
# 0       4884.273676  0.649278
# 1       3711.259791  0.205894
# 2       4672.270115  0.810345

# %%
Airlines[Airlines['clusteroid_new']==1]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 5        6    16420           0          1          1          1            0
# ...    ...      ...         ...        ...        ...        ...          ...
# 3993  4016     3974           0          1          1          1          365
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines[Airlines['clusteroid_new']==0]
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 4        5    97752           0          4          1          1        43300
# 6        7    84914           0          3          1          1        27482
# 9       10   104860           0          3          1          1        28426
# 11      12    96522           0          5          1          1        61105
# 15      16    28495           0          4          1          1        49442
# ...    ...      ...         ...        ...        ...        ...          ...
# 3979  4002    57793           0          3          1          1        20959
# 3980  4003    28867           0          3          1          1        19169
# 3985  4008    59017           0          4          1          1        34746
# 3991  4014    39142           0          3          1          1        14981
# 3996  4019    73597           0          3          1          1        25447
#
# ...

# %%
from sklearn.metrics import silhouette_score
score = silhouette_score(Scaled_Airlines_df, cluster_new.labels_,metric='euclidean')
score
# Out:
# 0.31110680893107867

# %%
Airlines1 = pd.DataFrame()
Airlines1['cluster_id']=cluster_new.labels_

# %%
Airlines1
# Out:
#       cluster_id
# 0              1
# 1              1
# 2              1
# 3              1
# 4              0
# ...          ...
# 3994           1
# 3995           1
# 3996           0
# 3997           1
# 3998           1
#
# [3999 rows x 1 columns]

# %% [markdown]
# #DBSCAN

# %% [markdown]
# # DBSCAN

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler

# %%
Airlines = pd.read_csv("EastWestAirlines (1).csv")
Airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
Airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
Airlines.rename(columns = {'Award?':'Award'}, inplace = True)

# %%
Airlines.drop(['ID#'],axis=1,inplace=True)
Airlines
# Out:
#       Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0       28143           0          1          1          1          174
# 1       19244           0          1          1          1          215
# 2       41354           0          1          1          1         4123
# 3       14776           0          1          1          1          500
# 4       97752           0          4          1          1        43300
# ...       ...         ...        ...        ...        ...          ...
# 3994    18476           0          1          1          1         8525
# 3995    64385           0          1          1          1          981
# 3996    73597           0          3          1          1        25447
# 3997    54899           0          1          1          1          500
# 3998     3016           0          1          1          1            0
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %%
array=Airlines.values
array
# Out:
# array([[28143,     0,     1, ...,     0,  7000,     0],
#        [19244,     0,     1, ...,     0,  6968,     0],
#        [41354,     0,     1, ...,     0,  7034,     0],
#        ...,
#        [73597,     0,     3, ...,     0,  1402,     1],
#        [54899,     0,     1, ...,     1,  1401,     0],
#        [ 3016,     0,     1, ...,     0,  1398,     0]], dtype=int64)

# %%
stscaler = StandardScaler()
X= stscaler.fit_transform(array)

# %%
X
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
from sklearn.neighbors import NearestNeighbors

nearest_neighbors = NearestNeighbors(n_neighbors=11)
neighbors = nearest_neighbors.fit(X)

distances ,indices = neighbors.kneighbors(X)
print(distances)

distances = np.sort(distances[:,10], axis=0)

fig = plt.figure(figsize=(5,5))
plt.plot(distances)
plt.Xlabel("Points")
plt.Ylabel("Distance")
plt.grid()
# Out:
# [[0.         0.11184685 0.12034246 ... 0.15881189 0.16026629 0.16537025]
#  [0.         0.11406276 0.11437601 ... 0.1921006  0.21071895 0.21081947]
#  [0.         0.16540223 0.19458949 ... 0.30691444 0.32157448 0.32480402]
#  ...
#  [0.         0.16614779 0.28024323 ... 0.77166854 0.78908622 0.82258359]
#  [0.         0.25725534 0.27167409 ... 0.46521438 0.47071907 0.47345856]
#  [0.         0.00270574 0.0112955  ... 0.06384821 0.08663803 0.09020918]]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[102], line 13
#      11 fig = plt.figure(figsize=(5,5))
#      12 plt.plot(distances)
# ---> 13 plt.Xlabel("Points")
#      14 plt.Ylabel("Distance")
#      15 plt.grid()
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'Xlabel'

# %%
from kneed import KneeLocator
i=np.arange(len(distance))
knee = KneesLocator(i,distances, S=1, curve='convex',direction='increasing',interp_method='polynomial')

fig = plt.figure(figsize=(5,5))
knee.plot_knee()
plt.Xlabel("points")
plt.Ylabe;l("Distance")
plt.grid()

print(distance[knee,knee])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 from kneed import KneeLocator
#       2 i=np.arange(len(distance))
#       3 knee = KneesLocator(i,distances, S=1, curve='convex',direction='increasing',interp_method='polynomial')
#
# ModuleNotFoundError: No module named 'kneed'

# %%
dbscan = DBSCAN(eps=1.5, min_samples=3)
clusters =dbscan.fit_predict(X)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 1, 0, 0], dtype=int64)

# %%
set(clusters)
# Out:
# {-1, 0, 1, 2, 3, 4, 5, 6, 7, 8}

# %%
Airlines['cluster']=dbscan
